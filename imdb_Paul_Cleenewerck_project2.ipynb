# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer: 

movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:

total_movies_duration = movies['duration'].mean()
print(total_movies_duration)
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:

movies_sorted_by_duration = movies.sort_values(by='duration')

print(movies_sorted_by_duration)
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:

plt.hist(movies['duration'])
# Out:
# (array([ 25., 168., 301., 259., 111.,  66.,  27.,  14.,   5.,   3.]),
#  array([ 64. ,  81.8,  99.6, 117.4, 135.2, 153. , 170.8, 188.6, 206.4,
#         224.2, 242. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:

plt.boxplot(movies['duration'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a050002240>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a050002c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a05000d908>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a05000d4e0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a050002390>,
#   <matplotlib.lines.Line2D at 0x1a050002828>]}

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
#Method 2 -  with Group By


movies.groupby(['content_rating'])['title'].count()
# Out:
# content_rating
# APPROVED      47
# G             32
# GP             3
# NC-17          7
# NOT RATED     65
# PASSED         7
# PG           123
# PG-13        189
# R            460
# TV-MA          1
# UNRATED       38
# X              4
# Name: title, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:

#Method 2 - with Plot

movies.content_rating.value_counts().plot(kind="bar")

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:

my_list = ['NOT RATED', 'APPROVED', 'PASSED', 'GP']

movies['content_rating'].replace([my_list], 'UNRATED', inplace = True)

movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:

movies['content_rating'].replace("NC-17", 'TV-MA', inplace = True)

movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:

movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:

movies['content_rating'].fillna('UNRATED', inplace=True)

movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    0
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    0
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:

movies.loc[movies['duration'] > 120, 'star_rating'] = movies['star_rating'].mean()

movies
# Out:
#      star_rating                                              title  \
# 0       7.889785                           The Shawshank Redemption
# 1       7.889785                                      The Godfather
# 2       7.889785                             The Godfather: Part II
# 3       7.889785                                    The Dark Knight
# 4       7.889785                                       Pulp Fiction
# 5       8.900000                                       12 Angry Men
# 6       7.889785                     The Good, the Bad and the Ugly
# 7       7.889785      The Lord of the Rings: The Return of the King
# 8       7.889785                                   Schindler's List
# 9       7.889785                                         Fight Club
# 10      7.889785  The Lord of the Rings: The Fellowship of the Ring
# 11      7.889785                                          Inception
# 12      7.889785     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:

np.random.seed(19680801)

N = 979
colors = np.random.rand(N)

plt.scatter(movies['star_rating'], movies['duration'], alpha = 0.5, c=colors)

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:

movies.groupby(['genre'])['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:

plt.scatter(x = movies['content_rating'], y = movies['duration'])

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
    
movies.sort_values(['title', 'star_rating'], ascending = False).groupby(['genre'])['title', 'star_rating'].max()
# Out:
#                                          title  star_rating
# genre
# Action                                 Yojimbo          8.6
# Adventure                            True Grit          8.5
# Animation                       Wreck-It Ralph          8.5
# Biography                        Walk the Line          8.6
# Comedy                              Zombieland          8.6
# Crime                                   Zodiac          8.7
# Drama                                     Zulu          8.9
# Family     Willy Wonka & the Chocolate Factory          7.9
# Fantasy              The City of Lost Children          7.7
# Film-Noir                        The Third Man          8.3
# History                    Battleship Potemkin          8.0
# Horror                                   [Rec]          8.6
# Mystery                                Vertigo          8.6
# Sci-Fi           The Day the Earth Stood Still          8.2
# Thriller             The Man Who Knew Too Much          8.0
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:

movies.duplicated('title', keep='first') == True


#When checked for duplicated all movietitles are all labeled as False,
#therefore, there does not seem to be duplicates here
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:


movies.groupby(['genre'])['title'].count() > 10

my_list = ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Drama', 'Horror', 'Mistery']

df = movies[movies.genre.isin(my_list)]

df.groupby(['genre'])['star_rating'].mean()
# Out:
# genre
# Action       7.842236
# Adventure    7.879068
# Animation    7.890947
# Biography    7.859468
# Comedy       7.803229
# Crime        7.894498
# Drama        7.885026
# Horror       7.801687
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:

genre_counts = movies.genre.value_counts()
top_genres = genre_counts[genre_counts >= 10].index


movies[movies.genre.isin(top_genres)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.842236
# Adventure    7.879068
# Animation    7.890947
# Biography    7.859468
# Comedy       7.803229
# Crime        7.894498
# Drama        7.885026
# Horror       7.801687
# Mystery      7.845531
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

movies.groupby('genre').star_rating.mean()[movies.genre.value_counts() >= 10]
# Out:
# genre
# Action       7.842236
# Adventure    7.879068
# Animation    7.890947
# Biography    7.859468
# Comedy       7.803229
# Crime        7.894498
# Drama        7.885026
# Horror       7.801687
# Mystery      7.845531
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

movies.groupby('genre').star_rating.agg(['mean'])[movies.genre.value_counts() >= 10]
# Out:
# C:\Users\pcleenewerck\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                mean
# genre
# Action     7.842236
# Adventure  7.879068
# Animation  7.890947
# Biography  7.859468
# Comedy     7.803229
# Crime      7.894498
# Drama      7.885026
# Horror     7.801687
# Mystery    7.845531

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
